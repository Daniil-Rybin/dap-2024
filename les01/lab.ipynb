# %% [markdown]
# # Отчет по Лабораторной работе №1 на тему "Подготовка среды для анализа данных"
# **Выполнил:** студент 3 курса группы 12002408
#
# Рыбин Даниил Евгеньевич
#
# **Проверил:** ассистент кафедры информационных и робототехнических систем
#
# Пузырев Никита Сергеевич

# %% [markdown]
# ## Задания для выполнения

# %% [markdown]
# 1. Создайте учетную запись в сервисе GitHub
# 2. Выполните форк репозитория https://github.com/chebotarevsa/dap-2024
# 3. Создайте учетную запись в [Google Colab](https://colab.research.google.com)
# 4. Настройте интеграцию Google Colab и GitHub
# 5. Создайте в Google Colab отчет о выполненой работе в виде файла rep.ipynb. Используйте Markdown разметку (заголовки, списки, форматированный текст, ссылки)
# 6. Сохраните отчет в ваш репозиторий github в директории ./les01
# 7. Создайте pull request в репозиторий https://github.com/chebotarevsa/dap-2024. Название pull request должно иметь формат "<Номер лабораторной работы>  <Номер группы> <ФИО>"
# 8. Сдайте работу в системе "Пегас", в отчет укажите ссылку на pull request

# %% [markdown]
# ## Ход работы

# %% [markdown]
# 1. Была создана учетная запись в Google Colab. На рисунке 1 представлен авторизованный пользователь. [Рисунок 1](https://drive.google.com/file/d/1XKIGbjPGc9tQpOWrjkMPLbFMu-nYXrPm/view?usp=drive_link)
#
# 2. Был выполнен форк репозитория. На рисунке 2 представлен репозиторий dap-2024. [Рисунок 2](https://drive.google.com/file/d/1tyo7nEyVApH-m9R8EA_BONPOfzRd3dtZ/view?usp=drive_link)
#
# 3. Была настроена интеграция Google Colab и GitHub. На рисунке 3 представлены связанные аккаунты. [Рисунок 3](https://drive.google.com/file/d/1o0QOvPizPNjAvKaw6r9T70luYgNH0qeu/view?usp=drive_link)

# %% [markdown]
# # Вывод
# В результате выполнения лабораторной работы был изучен инструмент Google Colab, а также создан форк репозитория и настроена интеграция с GitHub.
